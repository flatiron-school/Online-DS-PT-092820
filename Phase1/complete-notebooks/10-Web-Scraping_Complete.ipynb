# %% [markdown]
# # Web-Scraping

# %% [markdown]
# Hopefully, you can get all the data you need easily and accessibly, and don't need to scour the web to find a source that will let you do your analysis.
#
# We'd all prefer one of these:
#
# <img src="images/other_options.png" alt="image showcasing a downloadable csv, database connection, or API, but we're not always so lucky. not sure of image source, took from materials provided by another instructor" width=650>
#
# But we're not always so lucky! Sometimes we need data that's less accessible.

# %% [markdown]
# Enter...
#
# <img alt="beautiful soup logo" src="images/bs.png" width=500>
#
# > "You didn't write that awful page. You're just trying to get some data out of it. Beautiful Soup is here to help. Since 2004, it's been saving programmers hours or days of work on quick-turnaround screen scraping projects."
#
# - From the Beautiful Soup [documentation](https://www.crummy.com/software/BeautifulSoup/bs4/doc/#)

# %% [markdown]
# ## Grabbing Movie Data
#
# We might think about grabbing more movie data, as we gear up towards our Phase 1 project which uses movie data.
#
# If we go to [IMDB](https://www.imdb.com/), their only API content seems expensive, and their advanced search results in tabular data that seems _extremely_ scrapable.
#
# **BUT**
#
# Enter - [conditions of use pages](https://www.imdb.com/conditions) ... and ethics!
#
# > "**Robots and Screen Scraping:** You may not use data mining, robots, screen scraping, or similar data gathering and extraction tools on this site, except with our express written consent as noted below."
#
# **Let's Discuss**
#
# - Do people scrape sites they shouldn't? Sure, all the time. But am I going to tell you to ignore conditions/terms of use? Absolutely not. Make good choices.

# %% [markdown]
# Instead, let's scrape Wikipedia for movie data - Wikipedia has a very accessible Creative Commons license for use!
#
# Let's explore a few [years in film](https://en.wikipedia.org/wiki/Table_of_years_in_film).
#
# ## Task: Grab the top 10 highest-grossing films for each year, 2000-2019

# %% [markdown]
# ### Imports
#
# Our goal is to collect data into a Pandas dataframe. Plus we're still working with websites, so we'll still need the requests library.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup # note this odd import statement structure

# %%
# you may also need lxml - https://lxml.de/index.html
# helps process html or xml in python
# !pip install lxml

# %% [markdown]
# Test case - [the year 2000](https://en.wikipedia.org/wiki/2000_in_film).

# %%
# Get the response from the website, using requests
resp = requests.get("https://en.wikipedia.org/wiki/2000_in_film")

# %%
# Let's check out the text attribute of that response...
resp.text[:10000]
# (ew)
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>2000 in film - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"b58e6e78-392d-4bc6-8eae-db550e5cac40","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"2000_in_film","wgTitle":"2000 in film","wgCurRevisionId":986642426,"wgRevisionId":986642426,"wgArticleId":167091,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Short description is different from Wikidata","Use mdy dates from May 2019","2000 in film","Film by year"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"2000_in_film","wgRelevantArticleId":167091,"wgIsProbablyEditable":!0,\n"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0,"wgULSPosition":"interlanguage","wgWikibaseItemId":"Q753301"};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.styles.legacy":"ready","jquery.tablesorter.styles":"ready","jquery.makeCollapsible.styles":"ready",\n"mediawiki.toc.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","jquery.tablesorter","jquery.makeCollapsible","mediawiki.toc","skins.vector.legacy.js","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.extra-toolbar-buttons","ext.gadget.refToolbar","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp"];</script>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1hzgi",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});\n});});</script>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cjquery.tablesorter.styles%7Cmediawiki.toc.styles%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>\n<script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector"></script>\n<meta name="ResourceLoaderDynamicStyles" content=""/>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>\n<meta name="generator" content="MediaWiki 1.36.0-wmf.14"/>\n<meta name="referrer" content="origin"/>\n<meta name="referrer" content="origin-when-crossorigin"/>\n<meta name="referrer" content= ...

# %%
# And now... beautiful soup! Let's soup-ify that text attribute
soup = BeautifulSoup(resp.text)

# %%
# Can use a prettify function to pretty print
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    2000 in film - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"b58e6e78-392d-4bc6-8eae-db550e5cac40","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"2000_in_film","wgTitle":"2000 in film","wgCurRevisionId":986642426,"wgRevisionId":986642426,"wgArticleId":167091,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Short description is different from Wikidata","Use mdy dates from May 2019","2000 in film","Film by year"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"2000_in_film","wgRelevantArticleId":167091,"wgIsProbablyEditable":!0,
# "wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0,"wgULSPosition":"interlanguage","wgWikibaseItemId":"Q753301"};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.styles.legacy":"ready","jquery.tablesorter.styles":"ready","jquery.makeCollapsible.styles":"ready",
# "mediawiki.toc.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","jquery.tablesorter","jquery.makeCollapsible","mediawiki.toc","skins.vector.legacy.js","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.extra-toolbar-buttons","ext.gadget.refToolbar","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp"];
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1hzgi",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# });});
#   </script>
#   <link href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cjquery.tablesorter.styles%7Cmediawiki.toc.styles%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector">
#   </script>
#   <meta content="" name="ResourceLoaderDynamicStyles"/>
#   <link href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <meta content="MediaWiki 1.36.0-wmf.14" name="generator"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="origin-when-crossorigin" name="referrer"/>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <link href="//en.m.wikipedia.org/wiki/2000_in_film" media="only screen and (max-width: 720px)" rel="alternate"/>
#   <link href="/w/index.php?title=2000_in_film&amp;action=edit" rel="alternate" title="Edit this page" type="application/x-wiki"/>
#   <link href="/w/index.php?title=2000_in_film&amp;action=edit" rel="edit" title="Edit this page"/>
#   <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
#   <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>
#   <link href="/w/opensearch_desc.php" rel="search" title="Wikipedia (en)" type="application/opensearchdescription+xml"/>
#   <link href="//en.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
#   <link href="//creativecommons.org/licenses/by-sa/3.0/" rel="license"/>
#   <link href="https://en.wikipedia.org/wiki/2000_in_film" rel="canonical"/>
#   <link href="//login.wikimedia.org" rel="dns-prefetch"/>
#   <link href="//meta.wikimedia.org" rel="dns-prefetch"/>
#  </head>
#  <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-2000_in_film rootpage-2000_in_film skin-vector action-view skin-vector-legacy">
#   <div class="noprint" id="mw-page-base">
#   </div>
#   <div class="noprint" id="mw-head-base">
#   </div>
#   <div class="mw-body" id="content" role="main">
#    <a id="top">
#    </a>
#    <div class="mw-body-content" id="siteNotice">
#     <!-- CentralNotice -->
#    </div>
#    <div class="mw-indicators mw-body-content">
#    </div>
#    <h1 class="firstHeading" id="firstHeading" lang="en">
#     2000 in film
#    </h1>
#    <div class="mw-body-content" id="bodyContent">
#     <div class="noprint" id="siteSub">
#      From Wikipedia, the free encyclopedia
#     </div>
#     <div id="contentSub">
#     </div>
#     <div id="contentSub2">
#     </div>
#     <div id="jump-to-nav">
#     </div>
#     <a class="mw-jump-link" href="#mw-head">
#      Jump to navigation
#     </a>
#     <a class="mw-jump-link" href="#searchInput">
#      Jump to search
#     </a>
#     <div class="mw-content-ltr" dir="ltr" id="mw-content-text" lang="en">
#      <div class="mw-parser-output">
#       <div class="shortdescription nomobile noexcerpt noprint searchaux" style="display:none">
#        Overview of the events of 2000 in film
#       </div>
#       <p class="mw-empty-elt">
#       </p>
#       <div class="shortdescription nomobile noexcerpt noprint searchaux" style="display:none">
#        Overview of the events of 2000 in film
#       </div>
#       <table class="infobox hlist">
#        <tbody>
#         <tr>
#          <th style="font-size:larger;">
#           <table style="width:100%">
#            <tbody>
#             <tr>
#              <td style="text-align:left; width:5em;">
#              </td>
#              <td style="text-align:center">
#               <a href="/wiki/List_of_years_in_film" title="List of years in film">
#                List of years in film
#               </a>
#              </td>
#              <td style="text-align:right; width:5em;">
#               (
#               <a href="/wiki/Table_of_years_in_film" title="Table of years in film">
#                table
#               </a>
#               )
#              </td>
#             </tr>
#            </tbody>
#           </table>
#          </th>
#         </tr>
#         <tr>
#          <td style="text-align:center">
#           <ul>
#            <li>
#             <a href="/wiki/Category:Film_by_year" title="Category:Film by year">
#              …
#             </a>
#             <a href="/wiki/1990_in_film" title="1990 in film">
#              1990
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/1991_in_film" title="1991 in film">
#              1991
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/1992_in_film" title="1992 in film">
#              1992
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/1993_in_film" title="1993 in film">
#              1993
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/1994_in_film" title="1994 in film">
#              1994
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/1995_in_film" title="1995 in film">
#              1995
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/1996_in_film" title="1996 in film">
#              1996
#             </a>
#             <br/>
#            </li>
#            <li>
#             <a href="/wiki/1997_in_film" title="1997 in film">
#              1997
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/1998_in_film" title="1998 in film">
#              1998
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/1999_in_film" title="1999 in film">
#              1999
#             </a>
#            </li>
#            <li>
#             <b>
#              <a class="mw-selflink selflink">
#               2000
#              </a>
#             </b>
#            </li>
#            <li>
#             <a href="/wiki/2001_in_film" title="2001 in film">
#              2001
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/2002_in_film" title="2002 in film">
#              2002
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/2003_in_film" title="2003 in film">
#              2003
#             </a>
#             <br/>
#            </li>
#            <li>
#             <a href="/wiki/2004_in_film" title="2004 in film">
#              2004
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/2005_in_film" title="2005 in film">
#              2005
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/2006_in_film" title="2006 in film">
#              2006
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/2007_in_film" title="2007 in film">
#              2007
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/2008_in_film" title="2008 in film">
#              2008
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/2009_in_film" title="2009 in film">
#              2009
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/2010_in_film" title="2010 in film">
#              2010
#             </a>
#             <a href="/wiki/Category:Film_by_year" title="Category:Film by year">
#              …
#             </a>
#            </li>
#           </ul>
#          </td>
#         </tr>
#         <tr>
#          <td style="border-top:1px #aaa solid; padding-bottom:0;text-align:center;">
#           <div>
#            <dl>
#             <dt>
#              <style data-mw-deduplicate="TemplateStyles:r886047488">
#               .mw-parser-output .nobold{font-weight:normal}
#              </style>
#              <span class="nobold">
#               In home video
#              </span>
#             </dt>
#             <dd>
#              <a href="/wiki/1997_in_home_video" title="1997 in home video">
#               1997
#              </a>
#             </dd>
#             <dd>
#              <a href="/wiki/1998_in_home_video" title="1998 in home video">
#               1998
#              </a>
#             </dd>
#             <dd>
#              <a href="/wiki/1999_in_home_video" title="1999 in home video">
#               1999
#              </a>
#             </dd>
#             <dd>
#              <a href="/wiki/2000_in_home_video" title="2000 in home video">
#               2000
#              </a>
#             </dd>
#             <dd>
#              <a href="/wiki/2001_in_home_video" title="2001 in home video">
#               2001
#              </a>
#             </dd>
#             <dd>
#              <a href="/wiki/2002_in_home_video" title="2002 in home video">
#               2002
#              </a>
#             </dd>
#             <dd>
#              <a href="/wiki/2003_in_home_video" title="2003 in home video">
#               2003
#              </a>
#             </dd>
#            </dl>
#           </div>
#           <div>
#            <dl>
#             <dt>
#              <link href="mw-data:TemplateStyles:r886047488" rel="mw-deduplicated-inline-style"/>
#              <span class="nobold">
#               In television
#              </span>
#             </dt>
#             <dd>
#              <a href="/wiki/1997_in_television" title="1997 in television">
#               1997
#              </a>
#             </dd>
#             <dd>
#              <a href="/wiki/1998_in_television" title="1998 in television">
#               1998
#              </a>
#             </dd>
#             <dd>
#              <a href="/wiki/1999_in_television" title="1999 in television">
#               1999
#              </a>
#             </dd>
#             <dd>
#              <a href="/wiki/2000_in_television" title="2000 in television">
#               2000
#              </a>
#             </dd>
#             <dd>
#              <a href="/wiki/2001_in_television" title="2001 in television">
#               2001
#              </a>
#             </dd>
#             <dd>
#              <a href="/wiki/2002_in_television" title="2002 in television">
#               2002
#              </a>
#             </dd>
#             <dd>
#              <a href="/wiki/2003_in_television" title="2003 in television">
#               2003
#              </a>
#             </dd>
#            </dl>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <td style="text-align:center">
#           <ul>
#            <li>
#             <a href="/wiki/2000_in_art" title="2000 in art">
#              Art
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/2000_in_archaeology" title="2000 in archaeology">
#              Archaeology
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/2000_in_architecture" title="2000 in architecture">
#              Architecture
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/2000_in_literature" title="2000 in literature">
#              Literature
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/2000_in_music" title="2000 in music">
#              Music
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/2000_in_philosophy" title="2000 in philosophy">
#              Philosophy
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/2000_in_science" title="2000 in science">
#              Science
#             </a>
#             <i>
#              <a href="/wiki/Category:2000" title="Category:2000">
#               +...
#              </a>
#             </i>
#            </li>
#           </ul>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <table class="vertical-navbox nowraplinks hlist" style="float:right;clear:right;width:22.0em;margin:0 0 1.0em 1.0em;background:#f8f9fa;border:1px solid #aaa;padding:0.2em;border-spacing:0.4em 0;text-align:center;line-height:1.4em;font-size:88%;width:auto; min-width:18em;">
#        <tbody>
#         <tr>
#          <th class="navbox-title" style="padding:0.2em 0.4em 0.2em;font-size:145%;line-height:1.2em;font-size:140%;">
#           <a href="/wiki/List_of_years_in_film" title="List of years in film">
#            Years in film
#           </a>
#          </th>
#         </tr>
#         <tr>
#          <td style="padding:0.2em 0 0.4em">
#           <a href="/wiki/Film_reel" title="Film reel">
#            <img alt="A reel of film (vector logo)" data-file-height="48" data-file-width="48" decoding="async" height="80" src="//upload.wikimedia.org/wikipedia/en/thumb/e/e7/Video-x-generic.svg/80px-Video-x-generic.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/e/e7/Video-x-generic.svg/120px-Video-x-generic.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/e/e7/Video-x-generic.svg/160px-Video-x-generic.svg.png 2x" width="80"/>
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th style="padding:0.1em;background:lavender; border:#fff 1px solid; border-width:1px 1px 4px 1px;">
#           <a href="/wiki/1870s_in_film" title="1870s in film">
#            1870s
#           </a>
#          </th>
#         </tr>
#         <tr>
#          <td style="padding:0 0.1em 0.4em">
#           <div class="NavFrame collapsed" style="border:none;padding:0">
#            <div class="NavHead" style="font-size:105%;background:transparent;text-align:left;background:lavender; text-align:center;">
#             <a href="/wiki/1880s_in_film" title="1880s in film">
#              1880s
#             </a>
#            </div>
#            <div class="NavContent" style="font-size:105%;padding:0.2em 0 0.4em;text-align:center">
#             <ul>
#              <li>
#               <a href="/wiki/1880s_in_film" title="1880s in film">
#                1880
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1880s_in_film" title="1880s in film">
#                1881
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1880s_in_film" title="1880s in film">
#                1882
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1880s_in_film" title="1880s in film">
#                1883
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1880s_in_film" title="1880s in film">
#                1884
#               </a>
#              </li>
#             </ul>
#             <ul>
#              <li>
#               <a href="/wiki/1885_in_film" title="1885 in film">
#                1885
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1886_in_film" title="1886 in film">
#                1886
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1887_in_film" title="1887 in film">
#                1887
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1888_in_film" title="1888 in film">
#                1888
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1889_in_film" title="1889 in film">
#                1889
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <td style="padding:0 0.1em 0.4em">
#           <div class="NavFrame collapsed" style="border:none;padding:0">
#            <div class="NavHead" style="font-size:105%;background:transparent;text-align:left;background:lavender; text-align:center;">
#             <a href="/wiki/1890s_in_film" title="1890s in film">
#              1890s
#             </a>
#            </div>
#            <div class="NavContent" style="font-size:105%;padding:0.2em 0 0.4em;text-align:center">
#             <ul>
#              <li>
#               <a href="/wiki/1890_in_film" title="1890 in film">
#                1890
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1891_in_film" title="1891 in film">
#                1891
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1892_in_film" title="1892 in film">
#                1892
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1893_in_film" title="1893 in film">
#                1893
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1894_in_film" title="1894 in film">
#                1894
#               </a>
#              </li>
#             </ul>
#             <ul>
#              <li>
#               <a href="/wiki/1895_in_film" title="1895 in film">
#                1895
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1896_in_film" title="1896 in film">
#                1896
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1897_in_film" title="1897 in film">
#                1897
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1898_in_film" title="1898 in film">
#                1898
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1899_in_film" title="1899 in film">
#                1899
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <td style="padding:0 0.1em 0.4em">
#           <div class="NavFrame collapsed" style="border:none;padding:0">
#            <div class="NavHead" style="font-size:105%;background:transparent;text-align:left;background:lavender; text-align:center;">
#             <a href="/wiki/1900s_in_film" title="1900s in film">
#              1900s
#             </a>
#            </div>
#            <div class="NavContent" style="font-size:105%;padding:0.2em 0 0.4em;text-align:center">
#             <ul>
#              <li>
#               <a href="/wiki/1900_in_film" title="1900 in film">
#                1900
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1901_in_film" title="1901 in film">
#                1901
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1902_in_film" title="1902 in film">
#                1902
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1903_in_film" title="1903 in film">
#                1903
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1904_in_film" title="1904 in film">
#                1904
#               </a>
#              </li>
#             </ul>
#             <ul>
#              <li>
#               <a href="/wiki/1905_in_film" title="1905 in film">
#                1905
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1906_in_film" title="1906 in film">
#                1906
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1907_in_film" title="1907 in film">
#                1907
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1908_in_film" title="1908 in film">
#                1908
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1909_in_film" title="1909 in film">
#                1909
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <td style="padding:0 0.1em 0.4em">
#           <div class="NavFrame collapsed" style="border:none;padding:0">
#            <div class="NavHead" style="font-size:105%;background:transparent;text-align:left;background:lavender; text-align:center;">
#             <a href="/wiki/1910s_in_film" title="1910s in film">
#              1910s
#             </a>
#            </div>
#            <div class="NavContent" style="font-size:105%;padding:0.2em 0 0.4em;text-align:center">
#             <ul>
#              <li>
#               <a href="/wiki/1910_in_film" title="1910 in film">
#                1910
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1911_in_film" title="1911 in film">
#                1911
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1912_in_film" title="1912 in film">
#                1912
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1913_in_film" title="1913 in film">
#                1913
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1914_in_film" title="1914 in film">
#                1914
#               </a>
#              </li>
#             </ul>
#             <ul>
#              <li>
#               <a href="/wiki/1915_in_film" title="1915 in film">
#                1915
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1916_in_film" title="1916 in film">
#                1916
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1917_in_film" title="1917 in film">
#                1917
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1918_in_film" title="1918 in film">
#                1918
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1919_in_film" title="1919 in film">
#                1919
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <td style="padding:0 0.1em 0.4em">
#           <div class="NavFrame collapsed" style="border:none;padding:0">
#            <div class="NavHead" style="font-size:105%;background:transparent;text-align:left;background:lavender; text-align:center;">
#             <a href="/wiki/1920s_in_film" title="1920s in film">
#              1920s
#             </a>
#            </div>
#            <div class="NavContent" style="font-size:105%;padding:0.2em 0 0.4em;text-align:center">
#             <ul>
#              <li>
#               <a href="/wiki/1920_in_film" title="1920 in film">
#                1920
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1921_in_film" title="1921 in film">
#                1921
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1922_in_film" title="1922 in film">
#                1922
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1923_in_film" title="1923 in film">
#                1923
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1924_in_film" title="1924 in film">
#                1924
#               </a>
#              </li>
#             </ul>
#             <ul>
#              <li>
#               <a href="/wiki/1925_in_film" title="1925 in film">
#                1925
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1926_in_film" title="1926 in film">
#                1926
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1927_in_film" title="1927 in film">
#                1927
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1928_in_film" title="1928 in film">
#                1928
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1929_in_film" title="1929 in film">
#                1929
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <td style="padding:0 0.1em 0.4em">
#           <div class="NavFrame collapsed" style="border:none;padding:0">
#            <div class="NavHead" style="font-size:105%;background:transparent;text-align:left;background:lavender; text-align:center;">
#             <a href="/wiki/1930s_in_film" title="1930s in film">
#              1930s
#             </a>
#            </div>
#            <div class="NavContent" style="font-size:105%;padding:0.2em 0 0.4em;text-align:center">
#             <ul>
#              <li>
#               <a href="/wiki/1930_in_film" title="1930 in film">
#                1930
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1931_in_film" title="1931 in film">
#                1931
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1932_in_film" title="1932 in film">
#                1932
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1933_in_film" title="1933 in film">
#                1933
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1934_in_film" title="1934 in film">
#                1934
#               </a>
#              </li>
#             </ul>
#             <ul>
#              <li>
#               <a href="/wiki/1935_in_film" title="1935 in film">
#                1935
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1936_in_film" title="1936 in film">
#                1936
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1937_in_film" title="1937 in film">
#                1937
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1938_in_film" title="1938 in film">
#                1938
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1939_in_film" title="1939 in film">
#                1939
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <td style="padding:0 0.1em 0.4em">
#           <div class="NavFrame collapsed" style="border:none;padding:0">
#            <div class="NavHead" style="font-size:105%;background:transparent;text-align:left;background:lavender; text-align:center;">
#             <a href="/wiki/1940s_in_film" title="1940s in film">
#              1940s
#             </a>
#            </div>
#            <div class="NavContent" style="font-size:105%;padding:0.2em 0 0.4em;text-align:center">
#             <ul>
#              <li>
#               <a href="/wiki/1940_in_film" title="1940 in film">
#                1940
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1941_in_film" title="1941 in film">
#                1941
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1942_in_film" title="1942 in film">
#                1942
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1943_in_film" title="1943 in film">
#                1943
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1944_in_film" title="1944 in film">
#                1944
#               </a>
#              </li>
#             </ul>
#             <ul>
#              <li>
#               <a href="/wiki/1945_in_film" title="1945 in film">
#                1945
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1946_in_film" title="1946 in film">
#                1946
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1947_in_film" title="1947 in film">
#                1947
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1948_in_film" title="1948 in film">
#                1948
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1949_in_film" title="1949 in film">
#                1949
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <td style="padding:0 0.1em 0.4em">
#           <div class="NavFrame collapsed" style="border:none;padding:0">
#            <div class="NavHead" style="font-size:105%;background:transparent;text-align:left;background:lavender; text-align:center;">
#             <a href="/wiki/1950s_in_film" title="1950s in film">
#              1950s
#             </a>
#            </div>
#            <div class="NavContent" style="font-size:105%;padding:0.2em 0 0.4em;text-align:center">
#             <ul>
#              <li>
#               <a href="/wiki/1950_in_film" title="1950 in film">
#                1950
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1951_in_film" title="1951 in film">
#                1951
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1952_in_film" title="1952 in film">
#                1952
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1953_in_film" title="1953 in film">
#                1953
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1954_in_film" title="1954 in film">
#                1954
#               </a>
#              </li>
#             </ul>
#             <ul>
#              <li>
#               <a href="/wiki/1955_in_film" title="1955 in film">
#                1955
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1956_in_film" title="1956 in film">
#                1956
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1957_in_film" title="1957 in film">
#                1957
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1958_in_film" title="1958 in film">
#                1958
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1959_in_film" title="1959 in film">
#                1959
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <td style="padding:0 0.1em 0.4em">
#           <div class="NavFrame collapsed" style="border:none;padding:0">
#            <div class="NavHead" style="font-size:105%;background:transparent;text-align:left;background:lavender; text-align:center;">
#             <a href="/wiki/1960s_in_film" title="1960s in film">
#              1960s
#             </a>
#            </div>
#            <div class="NavContent" style="font-size:105%;padding:0.2em 0 0.4em;text-align:center">
#             <ul>
#              <li>
#               <a href="/wiki/1960_in_film" title="1960 in film">
#                1960
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1961_in_film" title="1961 in film">
#                1961
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1962_in_film" title="1962 in film">
#                1962
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1963_in_film" title="1963 in film">
#                1963
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1964_in_film" title="1964 in film">
#                1964
#               </a>
#              </li>
#             </ul>
#             <ul>
#              <li>
#               <a href="/wiki/1965_in_film" title="1965 in film">
#                1965
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1966_in_film" title="1966 in film">
#                1966
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1967_in_film" title="1967 in film">
#                1967
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1968_in_film" title="1968 in film">
#                1968
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1969_in_film" title="1969 in film">
#                1969
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <td style="padding:0 0.1em 0.4em">
#           <div class="NavFrame collapsed" style="border:none;padding:0">
#            <div class="NavHead" style="font-size:105%;background:transparent;text-align:left;background:lavender; text-align:center;">
#             <a href="/wiki/1970s_in_film" title="1970s in film">
#              1970s
#             </a>
#            </div>
#            <div class="NavContent" style="font-size:105%;padding:0.2em 0 0.4em;text-align:center">
#             <ul>
#              <li>
#               <a href="/wiki/1970_in_film" title="1970 in film">
#                1970
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1971_in_film" title="1971 in film">
#                1971
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1972_in_film" title="1972 in film">
#                1972
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1973_in_film" title="1973 in film">
#                1973
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1974_in_film" title="1974 in film">
#                1974
#               </a>
#              </li>
#             </ul>
#             <ul>
#              <li>
#               <a href="/wiki/1975_in_film" title="1975 in film">
#                1975
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1976_in_film" title="1976 in film">
#                1976
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1977_in_film" title="1977 in film">
#                1977
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1978_in_film" title="1978 in film">
#                1978
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1979_in_film" title="1979 in film">
#                1979
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <td style="padding:0 0.1em 0.4em">
#           <div class="NavFrame collapsed" style="border:none;padding:0">
#            <div class="NavHead" style="font-size:105%;background:transparent;text-align:left;background:lavender; text-align:center;">
#             <a href="/wiki/1980s_in_film" title="1980s in film">
#              1980s
#             </a>
#            </div>
#            <div class="NavContent" style="font-size:105%;padding:0.2em 0 0.4em;text-align:center">
#             <ul>
#              <li>
#               <a href="/wiki/1980_in_film" title="1980 in film">
#                1980
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1981_in_film" title="1981 in film">
#                1981
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1982_in_film" title="1982 in film">
#                1982
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1983_in_film" title="1983 in film">
#                1983
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1984_in_film" title="1984 in film">
#                1984
#               </a>
#              </li>
#             </ul>
#             <ul>
#              <li>
#               <a href="/wiki/1985_in_film" title="1985 in film">
#                1985
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1986_in_film" title="1986 in film">
#                1986
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1987_in_film" title="1987 in film">
#                1987
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1988_in_film" title="1988 in film">
#                1988
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1989_in_film" title="1989 in film">
#                1989
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <td style="padding:0 0.1em 0.4em">
#           <div class="NavFrame collapsed" style="border:none;padding:0">
#            <div class="NavHead" style="font-size:105%;background:transparent;text-align:left;background:lavender; text-align:center;">
#             <a href="/wiki/1990s_in_film" title="1990s in film">
#              1990s
#             </a>
#            </div>
#            <div class="NavContent" style="font-size:105%;padding:0.2em 0 0.4em;text-align:center">
#             <ul>
#              <li>
#               <a href="/wiki/1990_in_film" title="1990 in film">
#                1990
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1991_in_film" title="1991 in film">
#                1991
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1992_in_film" title="1992 in film">
#                1992
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1993_in_film" title="1993 in film">
#                1993
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1994_in_film" title="1994 in film">
#                1994
#               </a>
#              </li>
#             </ul>
#             <ul>
#              <li>
#               <a href="/wiki/1995_in_film" title="1995 in film">
#                1995
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1996_in_film" title="1996 in film">
#                1996
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1997_in_film" title="1997 in film">
#                1997
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1998_in_film" title="1998 in film">
#                1998
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/1999_in_film" title="1999 in film">
#                1999
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <td style="padding:0 0.1em 0.4em">
#           <div class="NavFrame" style="border:none;padding:0">
#            <div class="NavHead" style="font-size:105%;background:transparent;text-align:left;background:lavender; text-align:center;">
#             <a href="/wiki/2000s_in_film" title="2000s in film">
#              2000s
#             </a>
#            </div>
#            <div class="NavContent" style="font-size:105%;padding:0.2em 0 0.4em;text-align:center">
#             <ul>
#              <li>
#               <a class="mw-selflink selflink">
#                2000
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/2001_in_film" title="2001 in film">
#                2001
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/2002_in_film" title="2002 in film">
#                2002
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/2003_in_film" title="2003 in film">
#                2003
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/2004_in_film" title="2004 in film">
#                2004
#               </a>
#              </li>
#             </ul>
#             <ul>
#              <li>
#               <a href="/wiki/2005_in_film" title="2005 in film">
#                2005
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/2006_in_film" title="2006 in film">
#                2006
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/2007_in_film" title="2007 in film">
#                2007
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/2008_in_film" title="2008 in film">
#                2008
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/2009_in_film" title="2009 in film">
#                2009
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <td style="padding:0 0.1em 0.4em">
#           <div class="NavFrame collapsed" style="border:none;padding:0">
#            <div class="NavHead" style="font-size:105%;background:transparent;text-align:left;background:lavender; text-align:center;">
#             <a href="/wiki/2010s_in_film" title="2010s in film">
#              2010s
#             </a>
#            </div>
#            <div class="NavContent" style="font-size:105%;padding:0.2em 0 0.4em;text-align:center">
#             <ul>
#              <li>
#               <a href="/wiki/2010_in_film" title="2010 in film">
#                2010
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/2011_in_film" title="2011 in film">
#                2011
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/2012_in_film" title="2012 in film">
#                2012
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/2013_in_film" title="2013 in film">
#                2013
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/2014_in_film" title="2014 in film">
#                2014
#               </a>
#              </li>
#             </ul>
#             <ul>
#              <li>
#               <a href="/wiki/2015_in_film" title="2015 in film">
#                2015
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/2016_in_film" title="2016 in film">
#                2016
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/2017_in_film" title="2017 in film">
#                2017
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/2018_in_film" title="2018 in film">
#                2018
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/2019_in_film" title="2019 in film">
#                2019
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <td style="padding:0 0.1em 0.4em">
#           <div class="NavFrame collapsed" style="border:none;padding:0">
#            <div class="NavHead" style="font-size:105%;background:transparent;text-align:left;background:lavender; text-align:center;">
#             2020s
#            </div>
#            <div class="NavContent" style="font-size:105%;padding:0.2em 0 0.4em;text-align:center">
#             <ul>
#              <li>
#               <a href="/wiki/2020_in_film" title="2020 in film">
#                2020
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/2021_in_film" title="2021 in film">
#                2021
#               </a>
#              </li>
#              <li>
#               <a class="new" href="/w/index.php?title=2022_in_film&amp;action=edit&amp;redlink=1" title="2022 in film (page does not exist)">
#                2022
#               </a>
#              </li>
#              <li>
#               <a class="new" href="/w/index.php?title=2023_in_film&amp;action=edit&amp;redlink=1" title="2023 in film (page does not exist)">
#                2023
#               </a>
#              </li>
#              <li>
#               <a class="new" href="/w/index.php?title=2024_in_film&amp;action=edit&amp;redlink=1" title="2024 in film (page does not exist)">
#                2024
#               </a>
#              </li>
#             </ul>
#             <ul>
#              <li>
#               <a class="new" href="/w/index.php?title=2025_in_film&amp;action=edit&amp;redlink=1" title="2025 in film (page does not exist)">
#                2025
#               </a>
#              </li>
#              <li>
#               <a class="new" href="/w/index.php?title=2026_in_film&amp;action=edit&amp;redlink=1" title="2026 in film (page does not exist)">
#                2026
#               </a>
#              </li>
#              <li>
#               <a class="new" href="/w/index.php?title=2027_in_film&amp;action=edit&amp;redlink=1" title="2027 in film (page does not exist)">
#                2027
#               </a>
#              </li>
#              <li>
#               <a class="new" href="/w/index.php?title=2028_in_film&amp;action=edit&amp;redlink=1" title="2028 in film (page does not exist)">
#                2028
#               </a>
#              </li>
#              <li>
#               <a class="new" href="/w/index.php?title=2029_in_film&amp;action=edit&amp;redlink=1" title="2029 in film (page does not exist)">
#                2029
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <td style="text-align:right;font-size:115%;padding-top: 0.6em;padding-top:0">
#           <div class="plainlinks hlist navbar mini">
#            <ul>
#             <li class="nv-view">
#              <a href="/wiki/Template:Years_in_film" title="Template:Years in film">
#               <abbr title="View this template">
#                v
#               </abbr>
#              </a>
#             </li>
#             <li class="nv-talk">
#              <a href="/wiki/Template_talk:Years_in_film" title="Template talk:Years in film">
#               <abbr title="Discuss this template">
#                t
#               </abbr>
#              </a>
#             </li>
#             <li class="nv-edit">
#              <a class="external text" href="https://en.wikipedia.org/w/index.php?title=Template:Years_in_film&amp;action=edit">
#               <abbr title="Edit this template">
#                e
#               </abbr>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <p>
#        The year
#        <b>
#         2000 in film
#        </b>
#        involved some significant events.
# ...
#        Print/export
#       </span>
#      </h3>
#      <div class="vector-menu-content">
#       <ul class="vector-menu-content-list">
#        <li id="coll-download-as-rl">
#         <a href="/w/index.php?title=Special:DownloadAsPdf&amp;page=2000_in_film&amp;action=show-download-screen" title="Download this page as a PDF file">
#          Download as PDF
#         </a>
#        </li>
#        <li id="t-print">
#         <a accesskey="p" href="/w/index.php?title=2000_in_film&amp;printable=yes" title="Printable version of this page [p]">
#          Printable version
#         </a>
#        </li>
#       </ul>
#      </div>
#     </nav>
#     <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
#     <nav aria-labelledby="p-wikibase-otherprojects-label" class="mw-portlet mw-portlet-wikibase-otherprojects vector-menu vector-menu-portal portal" id="p-wikibase-otherprojects" role="navigation">
#      <h3 id="p-wikibase-otherprojects-label">
#       <span>
#        In other projects
#       </span>
#      </h3>
#      <div class="vector-menu-content">
#       <ul class="vector-menu-content-list">
#        <li class="wb-otherproject-link wb-otherproject-commons">
#         <a href="https://commons.wikimedia.org/wiki/Category:2000_in_film" hreflang="en">
#          Wikimedia Commons
#         </a>
#        </li>
#       </ul>
#      </div>
#     </nav>
#     <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
#     <nav aria-labelledby="p-lang-label" class="mw-portlet mw-portlet-lang vector-menu vector-menu-portal portal" id="p-lang" role="navigation">
#      <h3 id="p-lang-label">
#       <span>
#        Languages
#       </span>
#      </h3>
#      <div class="vector-menu-content">
#       <ul class="vector-menu-content-list">
#        <li class="interlanguage-link interwiki-az">
#         <a class="interlanguage-link-target" href="https://az.wikipedia.org/wiki/2000-ci_ilin_filml%C9%99ri" hreflang="az" lang="az" title="2000-ci ilin filmləri – Azerbaijani">
#          Azərbaycanca
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-be">
#         <a class="interlanguage-link-target" href="https://be.wikipedia.org/wiki/2000_%D0%B3%D0%BE%D0%B4_%D1%83_%D0%B3%D1%96%D1%81%D1%82%D0%BE%D1%80%D1%8B%D1%96_%D0%BA%D1%96%D0%BD%D0%BE" hreflang="be" lang="be" title="2000 год у гісторыі кіно – Belarusian">
#          Беларуская
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-bg">
#         <a class="interlanguage-link-target" href="https://bg.wikipedia.org/wiki/%D0%9A%D0%B8%D0%BD%D0%BE_%D0%BF%D1%80%D0%B5%D0%B7_2000_%D0%B3%D0%BE%D0%B4%D0%B8%D0%BD%D0%B0" hreflang="bg" lang="bg" title="Кино през 2000 година – Bulgarian">
#          Български
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-cs">
#         <a class="interlanguage-link-target" href="https://cs.wikipedia.org/wiki/2000_ve_filmu" hreflang="cs" lang="cs" title="2000 ve filmu – Czech">
#          Čeština
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-de">
#         <a class="interlanguage-link-target" href="https://de.wikipedia.org/wiki/Filmjahr_2000" hreflang="de" lang="de" title="Filmjahr 2000 – German">
#          Deutsch
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-es">
#         <a class="interlanguage-link-target" href="https://es.wikipedia.org/wiki/Anexo:Cine_en_2000" hreflang="es" lang="es" title="Anexo:Cine en 2000 – Spanish">
#          Español
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-fa">
#         <a class="interlanguage-link-target" href="https://fa.wikipedia.org/wiki/%D9%81%DB%8C%D9%84%D9%85_%D8%AF%D8%B1_%DB%B2%DB%B0%DB%B0%DB%B0" hreflang="fa" lang="fa" title="فیلم در ۲۰۰۰ – Persian">
#          فارسی
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-fr">
#         <a class="interlanguage-link-target" href="https://fr.wikipedia.org/wiki/2000_au_cin%C3%A9ma" hreflang="fr" lang="fr" title="2000 au cinéma – French">
#          Français
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ga">
#         <a class="interlanguage-link-target" href="https://ga.wikipedia.org/wiki/2000_sa_scann%C3%A1n" hreflang="ga" lang="ga" title="2000 sa scannán – Irish">
#          Gaeilge
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-hr">
#         <a class="interlanguage-link-target" href="https://hr.wikipedia.org/wiki/Film_u_2000." hreflang="hr" lang="hr" title="Film u 2000. – Croatian">
#          Hrvatski
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-id">
#         <a class="interlanguage-link-target" href="https://id.wikipedia.org/wiki/Film_dalam_tahun_2000" hreflang="id" lang="id" title="Film dalam tahun 2000 – Indonesian">
#          Bahasa Indonesia
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-he">
#         <a class="interlanguage-link-target" href="https://he.wikipedia.org/wiki/2000_%D7%91%D7%A7%D7%95%D7%9C%D7%A0%D7%95%D7%A2" hreflang="he" lang="he" title="2000 בקולנוע – Hebrew">
#          עברית
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ky">
#         <a class="interlanguage-link-target" href="https://ky.wikipedia.org/wiki/2000_%D0%B6%D1%8B%D0%BB%D0%B4%D0%B0%D0%B3%D1%8B_%D0%BA%D0%B8%D0%BD%D0%BE" hreflang="ky" lang="ky" title="2000 жылдагы кино – Kyrgyz">
#          Кыргызча
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-hu">
#         <a class="interlanguage-link-target" href="https://hu.wikipedia.org/wiki/2000_a_filmm%C5%B1v%C3%A9szetben" hreflang="hu" lang="hu" title="2000 a filmművészetben – Hungarian">
#          Magyar
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-mk">
#         <a class="interlanguage-link-target" href="https://mk.wikipedia.org/wiki/2000_%D0%B2%D0%BE_%D1%84%D0%B8%D0%BB%D0%BC%D0%BE%D1%82" hreflang="mk" lang="mk" title="2000 во филмот – Macedonian">
#          Македонски
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-mr">
#         <a class="interlanguage-link-target" href="https://mr.wikipedia.org/wiki/%E0%A4%87.%E0%A4%B8._%E0%A5%A8%E0%A5%A6%E0%A5%A6%E0%A5%A6_%E0%A4%AE%E0%A4%A7%E0%A5%80%E0%A4%B2_%E0%A4%9A%E0%A4%BF%E0%A4%A4%E0%A5%8D%E0%A4%B0%E0%A4%AA%E0%A4%9F" hreflang="mr" lang="mr" title="इ.स. २००० मधील चित्रपट – Marathi">
#          मराठी
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-nl">
#         <a class="interlanguage-link-target" href="https://nl.wikipedia.org/wiki/Film_in_2000" hreflang="nl" lang="nl" title="Film in 2000 – Dutch">
#          Nederlands
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ja">
#         <a class="interlanguage-link-target" href="https://ja.wikipedia.org/wiki/2000%E5%B9%B4%E3%81%AE%E6%98%A0%E7%94%BB" hreflang="ja" lang="ja" title="2000年の映画 – Japanese">
#          日本語
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-no">
#         <a class="interlanguage-link-target" href="https://no.wikipedia.org/wiki/Film%C3%A5ret_2000" hreflang="nb" lang="nb" title="Filmåret 2000 – Norwegian Bokmål">
#          Norsk bokmål
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-pnb">
#         <a class="interlanguage-link-target" href="https://pnb.wikipedia.org/wiki/%D9%81%D9%84%D9%85_%D9%88%DA%86_2000%D8%A1" hreflang="pnb" lang="pnb" title="فلم وچ 2000ء – Western Punjabi">
#          پنجابی
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-pl">
#         <a class="interlanguage-link-target" href="https://pl.wikipedia.org/wiki/2000_w_filmie" hreflang="pl" lang="pl" title="2000 w filmie – Polish">
#          Polski
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-pt">
#         <a class="interlanguage-link-target" href="https://pt.wikipedia.org/wiki/2000_no_cinema" hreflang="pt" lang="pt" title="2000 no cinema – Portuguese">
#          Português
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ro">
#         <a class="interlanguage-link-target" href="https://ro.wikipedia.org/wiki/2000_%C3%AEn_film" hreflang="ro" lang="ro" title="2000 în film – Romanian">
#          Română
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ru">
#         <a class="interlanguage-link-target" href="https://ru.wikipedia.org/wiki/2000_%D0%B3%D0%BE%D0%B4_%D0%B2_%D0%BA%D0%B8%D0%BD%D0%BE" hreflang="ru" lang="ru" title="2000 год в кино – Russian">
#          Русский
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-sq">
#         <a class="interlanguage-link-target" href="https://sq.wikipedia.org/wiki/2000_n%C3%AB_film" hreflang="sq" lang="sq" title="2000 në film – Albanian">
#          Shqip
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-sh">
#         <a class="interlanguage-link-target" href="https://sh.wikipedia.org/wiki/2000._na_filmu" hreflang="sh" lang="sh" title="2000. na filmu – Serbo-Croatian">
#          Srpskohrvatski / српскохрватски
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-fi">
#         <a class="interlanguage-link-target" href="https://fi.wikipedia.org/wiki/Elokuvavuosi_2000" hreflang="fi" lang="fi" title="Elokuvavuosi 2000 – Finnish">
#          Suomi
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-sv">
#         <a class="interlanguage-link-target" href="https://sv.wikipedia.org/wiki/Film%C3%A5ret_2000" hreflang="sv" lang="sv" title="Filmåret 2000 – Swedish">
#          Svenska
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-uk">
#         <a class="interlanguage-link-target" href="https://uk.wikipedia.org/wiki/2000_%D1%83_%D0%BA%D1%96%D0%BD%D0%BE" hreflang="uk" lang="uk" title="2000 у кіно – Ukrainian">
#          Українська
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ur">
#         <a class="interlanguage-link-target" href="https://ur.wikipedia.org/wiki/%D9%81%D9%84%D9%85_%D9%85%DB%8C%DA%BA_2000%D8%A1" hreflang="ur" lang="ur" title="فلم میں 2000ء – Urdu">
#          اردو
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-zh">
#         <a class="interlanguage-link-target" href="https://zh.wikipedia.org/wiki/2000%E5%B9%B4%E7%94%B5%E5%BD%B1" hreflang="zh" lang="zh" title="2000年电影 – Chinese">
#          中文
#         </a>
#        </li>
#       </ul>
#       <div class="after-portlet after-portlet-lang">
#        <span class="wb-langlinks-edit wb-langlinks-link">
#         <a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q753301#sitelinks-wikipedia" title="Edit interlanguage links">
#          Edit links
#         </a>
#        </span>
#       </div>
#      </div>
#     </nav>
#    </div>
#   </div>
#   <footer class="mw-footer" id="footer" role="contentinfo">
#    <ul id="footer-info">
#     <li id="footer-info-lastmod">
#      This page was last edited on 2 November 2020, at 03:17
#      <span class="anonymous-show">
#       (UTC)
#      </span>
#      .
#     </li>
#     <li id="footer-info-copyright">
#      Text is available under the
#      <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License" rel="license">
#       Creative Commons Attribution-ShareAlike License
#      </a>
#      <a href="//creativecommons.org/licenses/by-sa/3.0/" rel="license" style="display:none;">
#      </a>
#      ;
# additional terms may apply.  By using this site, you agree to the
#      <a href="//foundation.wikimedia.org/wiki/Terms_of_Use">
#       Terms of Use
#      </a>
#      and
#      <a href="//foundation.wikimedia.org/wiki/Privacy_policy">
#       Privacy Policy
#      </a>
#      . Wikipedia® is a registered trademark of the
#      <a href="//www.wikimediafoundation.org/">
#       Wikimedia Foundation, Inc.
#      </a>
#      , a non-profit organization.
#     </li>
#    </ul>
#    <ul id="footer-places">
#     <li id="footer-places-privacy">
#      <a class="extiw" href="https://foundation.wikimedia.org/wiki/Privacy_policy" title="wmf:Privacy policy">
#       Privacy policy
#      </a>
#     </li>
#     <li id="footer-places-about">
#      <a href="/wiki/Wikipedia:About" title="Wikipedia:About">
#       About Wikipedia
#      </a>
#     </li>
#     <li id="footer-places-disclaimer">
#      <a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">
#       Disclaimers
#      </a>
#     </li>
#     <li id="footer-places-contact">
#      <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">
#       Contact Wikipedia
#      </a>
#     </li>
#     <li id="footer-places-mobileview">
#      <a class="noprint stopMobileRedirectToggle" href="//en.m.wikipedia.org/w/index.php?title=2000_in_film&amp;mobileaction=toggle_view_mobile">
#       Mobile view
#      </a>
#     </li>
#     <li id="footer-places-developers">
#      <a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">
#       Developers
#      </a>
#     </li>
#     <li id="footer-places-statslink">
#      <a href="https://stats.wikimedia.org/#/en.wikipedia.org">
#       Statistics
#      </a>
#     </li>
#     <li id="footer-places-cookiestatement">
#      <a href="https://foundation.wikimedia.org/wiki/Cookie_statement">
#       Cookie statement
#      </a>
#     </li>
#    </ul>
#    <ul class="noprint" id="footer-icons">
#     <li id="footer-copyrightico">
#      <a href="https://wikimediafoundation.org/">
#       <img alt="Wikimedia Foundation" height="31" loading="lazy" src="/static/images/footer/wikimedia-button.png" srcset="/static/images/footer/wikimedia-button-1.5x.png 1.5x, /static/images/footer/wikimedia-button-2x.png 2x" width="88"/>
#      </a>
#     </li>
#     <li id="footer-poweredbyico">
#      <a href="https://www.mediawiki.org/">
#       <img alt="Powered by MediaWiki" height="31" loading="lazy" src="/static/images/footer/poweredby_mediawiki_88x31.png" srcset="/static/images/footer/poweredby_mediawiki_132x47.png 1.5x, /static/images/footer/poweredby_mediawiki_176x62.png 2x" width="88"/>
#      </a>
#     </li>
#    </ul>
#    <div style="clear: both;">
#    </div>
#   </footer>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"1.492","walltime":"1.780","ppvisitednodes":{"value":8745,"limit":1000000},"postexpandincludesize":{"value":91046,"limit":2097152},"templateargumentsize":{"value":1628,"limit":2097152},"expansiondepth":{"value":13,"limit":40},"expensivefunctioncount":{"value":5,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":10478,"limit":5000000},"entityaccesscount":{"value":0,"limit":400},"timingprofile":["100.00%  475.055      1 -total"," 30.45%  144.633    139 Template:Hlist"," 23.22%  110.293      1 Template:Reflist"," 19.47%   92.470      2 Template:Cite_web"," 16.96%   80.584      2 Template:Short_description","  9.49%   45.070      2 Template:Pagetype","  6.59%   31.312      1 Template:Year_nav_topic5","  6.11%   29.030      1 Template:Yearsinfilm","  5.70%   27.097      1 Template:Use_mdy_dates","  4.74%   22.502      1 Template:Sidebar_with_collapsible_lists"]},"scribunto":{"limitreport-timeusage":{"value":"0.233","limit":"10.000"},"limitreport-memusage":{"value":3482144,"limit":52428800}},"cachereport":{"origin":"mw1284","timestamp":"20201102031643","ttl":2592000,"transientcontent":false}}});});
#   </script>
#   <script type="application/ld+json">
#    {"@context":"https:\/\/schema.org","@type":"Article","name":"2000 in film","url":"https:\/\/en.wikipedia.org\/wiki\/2000_in_film","sameAs":"http:\/\/www.wikidata.org\/entity\/Q753301","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q753301","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2003-01-09T02:49:28Z","dateModified":"2020-11-02T03:17:03Z","headline":"overview of the events of the year 2000 in film"}
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":143,"wgHostname":"mw1323"});});
#   </script>
#  </body>
# </html>

# %%
soup.get_text()[:10000]
# Out:
# '\n\n\n2000 in film - Wikipedia\ndocument.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"b58e6e78-392d-4bc6-8eae-db550e5cac40","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"2000_in_film","wgTitle":"2000 in film","wgCurRevisionId":986642426,"wgRevisionId":986642426,"wgArticleId":167091,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Short description is different from Wikidata","Use mdy dates from May 2019","2000 in film","Film by year"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"2000_in_film","wgRelevantArticleId":167091,"wgIsProbablyEditable":!0,\n"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0,"wgULSPosition":"interlanguage","wgWikibaseItemId":"Q753301"};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.styles.legacy":"ready","jquery.tablesorter.styles":"ready","jquery.makeCollapsible.styles":"ready",\n"mediawiki.toc.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","jquery.tablesorter","jquery.makeCollapsible","mediawiki.toc","skins.vector.legacy.js","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.extra-toolbar-buttons","ext.gadget.refToolbar","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp"];\n(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1hzgi",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});\n});});\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n2000 in film\n\nFrom Wikipedia, the free encyclopedia\n\n\n\nJump to navigation\nJump to search\nOverview of the events of 2000 in film\n\n\nOverview of the events of 2000 in film\n\n\n\n\n\n\n\nList of years in film\n\n(table)\n\n\n\n\n… 1990\n1991\n1992\n1993\n1994\n1995\n1996\n1997\n1998\n1999\n2000\n2001\n2002\n2003\n2004\n2005\n2006\n2007\n2008\n2009\n2010 …\n\n\n\n\n.mw-parser-output .nobold{font-weight:normal}In home video\n1997\n1998\n1999\n2000\n2001\n2002\n2003\n\n\nIn television\n1997\n1998\n1999\n2000\n2001\n2002\n2003\n\n\n\n\nArt\nArchaeology\nArchitecture\nLiterature\nMusic\nPhilosophy\nScience +...\n\nYears in film\n1870s\n1880s\n1880\n1881\n1882\n1883\n1884\n1885\n1886\n1887\n1888\n1889\n\n1890s\n1890\n1891\n1892\n1893\n1894\n1895\n1896\n1897\n1898\n1899\n\n1900s\n1900\n1901\n1902\n1903\n1904\n1905\n1906\n1907\n1908\n1909\n\n1910s\n1910\n1911\n1912\n1913\n1914\n1915\n1916\ ...

# %%
# Now we need to find the table we want in the soup - use .find()
# Can pass a dictionary in the attributes argument
table = soup.find('table', {'class': "wikitable sortable"})

# %%
table
# Out:
# <table class="wikitable sortable" style="margin:auto; margin:auto;">
# <caption>Highest-grossing films of 2000
# </caption>
# <tbody><tr>
# <th>Rank</th>
# <th>Title</th>
# <th>Distributor</th>
# <th>Worldwide gross
# </th></tr>
# <tr>
# <th style="text-align:center;">1
# </th>
# <td><i><a href="/wiki/Mission:_Impossible_2" title="Mission: Impossible 2">Mission: Impossible 2</a></i>
# </td>
# <td><a href="/wiki/Paramount_Pictures" title="Paramount Pictures">Paramount</a>
# </td>
# <td>$546,388,105
# </td></tr>
# <tr>
# <th style="text-align:center;">2
# </th>
# <td><i><a href="/wiki/Gladiator_(2000_film)" title="Gladiator (2000 film)">Gladiator</a></i>
# </td>
# <td><a href="/wiki/Universal_Pictures" title="Universal Pictures">Universal</a>
# </td>
# <td>$460,583,960
# </td></tr>
# <tr>
# <th style="text-align:center;">3
# </th>
# <td><i><a href="/wiki/Cast_Away" title="Cast Away">Cast Away</a></i>
# </td>
# <td><a class="mw-redirect" href="/wiki/20th_Century_Fox" title="20th Century Fox">20th Century Fox</a>
# </td>
# <td>$429,632,142
# </td></tr>
# <tr>
# <th style="text-align:center;">4
# </th>
# <td><i><a href="/wiki/What_Women_Want" title="What Women Want">What Women Want</a></i>
# </td>
# <td>Paramount
# </td>
# <td>$374,111,707
# </td></tr>
# <tr>
# <th style="text-align:center;">5
# </th>
# <td><i><a href="/wiki/Dinosaur_(film)" title="Dinosaur (film)">Dinosaur</a></i>
# </td>
# <td><a href="/wiki/Walt_Disney_Studios_Motion_Pictures" title="Walt Disney Studios Motion Pictures">Disney</a>
# </td>
# <td>$349,822,765
# </td></tr>
# <tr>
# <th style="text-align:center;">6
# </th>
# <td><i><a href="/wiki/How_the_Grinch_Stole_Christmas_(2000_film)" title="How the Grinch Stole Christmas (2000 film)">How the Grinch Stole Christmas</a></i>
# </td>
# <td rowspan="2">Universal
# </td>
# <td>$345,141,403
# </td></tr>
# <tr>
# <th style="text-align:center;">7
# </th>
# <td><i><a href="/wiki/Meet_the_Parents" title="Meet the Parents">Meet the Parents</a></i>
# </td>
# <td>$330,444,045
# </td></tr>
# <tr>
# <th style="text-align:center;">8
# </th>
# <td><i><a href="/wiki/The_Perfect_Storm_(film)" title="The Perfect Storm (film)">The Perfect Storm</a></i>
# </td>
# <td><a href="/wiki/Warner_Bros." title="Warner Bros.">Warner Bros.</a>
# </td>
# <td>$328,718,434
# </td></tr>
# <tr>
# <th style="text-align:center;">9
# </th>
# <td><i><a href="/wiki/X-Men_(film)" title="X-Men (film)">X-Men</a></i>
# </td>
# <td rowspan="2">20th Century Fox
# </td>
# <td>$296,339,527
# </td></tr>
# <tr>
# <th style="text-align:center;">10
# </th>
# <td><i><a href="/wiki/What_Lies_Beneath" title="What Lies Beneath">What Lies Beneath</a></i>
# </td>
# <td>$291,420,351
# </td></tr></tbody></table>

# %%
# Explore that result
len(table.find_all('tr'))
# Out:
# 11

# %%
# Check out the first real row in the table
table.find_all('tr')[1].get_text().split("\n\n")
# Out:
# ['\n1', 'Mission: Impossible 2', 'Paramount', '$546,388,105\n']

# %%
# Check out the last row... what's missing?
table.find_all('tr')[10].get_text().split("\n\n")
# Out:
# ['\n10', 'What Lies Beneath', '$291,420,351\n']

# %% [markdown]
# **But wait...** there's a shortcut (thanks pandas)

# %%
# Note - pandas likes the prettify objects better
df = pd.read_html(table.prettify())

# %%
# Check our work
df[0]
# Out:
#    Rank                           Title       Distributor Worldwide gross
# 0     1           Mission: Impossible 2         Paramount    $546,388,105
# 1     2                       Gladiator         Universal    $460,583,960
# 2     3                       Cast Away  20th Century Fox    $429,632,142
# 3     4                 What Women Want         Paramount    $374,111,707
# 4     5                        Dinosaur            Disney    $349,822,765
# 5     6  How the Grinch Stole Christmas         Universal    $345,141,403
# 6     7                Meet the Parents         Universal    $330,444,045
# 7     8               The Perfect Storm      Warner Bros.    $328,718,434
# 8     9                           X-Men  20th Century Fox    $296,339,527
# 9    10               What Lies Beneath  20th Century Fox    $291,420,351

# %%
df[0]['Year'] = 2000

# %%
df[0]
# Out:
#    Rank                           Title       Distributor Worldwide gross  \
# 0     1           Mission: Impossible 2         Paramount    $546,388,105
# 1     2                       Gladiator         Universal    $460,583,960
# 2     3                       Cast Away  20th Century Fox    $429,632,142
# 3     4                 What Women Want         Paramount    $374,111,707
# 4     5                        Dinosaur            Disney    $349,822,765
# 5     6  How the Grinch Stole Christmas         Universal    $345,141,403
# 6     7                Meet the Parents         Universal    $330,444,045
# 7     8               The Perfect Storm      Warner Bros.    $328,718,434
# 8     9                           X-Men  20th Century Fox    $296,339,527
# 9    10               What Lies Beneath  20th Century Fox    $291,420,351
#
#    Year
# 0  2000
# 1  2000
# 2  2000
# 3  2000
# 4  2000
# 5  2000
# 6  2000
# 7  2000
# 8  2000
# 9  2000

# %% [markdown]
# ### Now Loop It!
#
# 2000 - 2020

# %%
resp
# Out:
# <Response [200]>

# %%
# My preference - create a list of dataframes, then concat afterwards
# Are there other ways to create one big df from this? OF COURSE!
list_of_dfs = []

for year in range(2000, 2021):
    url = f"https://en.wikipedia.org/wiki/{year}_in_film"
    resp = requests.get(url).text
    soup = BeautifulSoup(resp)
    table = soup.find('table', {'class': "wikitable sortable"})
    df = pd.read_html(table.prettify())
    df = df[0]
    df['Year'] = year
    list_of_dfs.append(df)


# Only 20 things... not going to worry about using time to pause requests

# %%
# Check our work
list_of_dfs[-1]
# Out:
#    Rank                         Title                   Distributor  \
# 0     1             The Eight Hundred         CMC Pictures Holdings
# 1     2        My People, My Homeland  China Lion Film Distribution
# 2     3             Bad Boys for Life                          Sony
# 3     4                         Tenet                  Warner Bros.
# 4     5            Sonic the Hedgehog                     Paramount
# 5     6                      Dolittle                     Universal
# 6     7                    Jiang Ziya      Beijing Enlight Pictures
# 7     8                 Birds of Prey                  Warner Bros.
# 8     9  Demon Slayer: Infinity Train              Toho  /  Aniplex
# 9    10                        Onward                        Disney
#
#   Worldwide gross  Year
# 0    $464,760,324  2020
# 1    $450,064,993  2020
# 2    $424,505,244  2020
# 3    $347,100,000  2020
# 4    $308,434,533  2020
# 5    $250,482,863  2020
# 6    $235,155,430  2020
# 7    $201,858,461  2020
# 8    $150,000,000  2020
# 9    $144,983,422  2020

# %%
# Now to concat...
full_df = pd.concat([df for df in list_of_dfs], ignore_index = True)

# %%
full_df.head()
# Out:
#    Rank                  Title       Distributor Worldwide gross  Year
# 0     1  Mission: Impossible 2         Paramount    $546,388,105  2000
# 1     2              Gladiator         Universal    $460,583,960  2000
# 2     3              Cast Away  20th Century Fox    $429,632,142  2000
# 3     4        What Women Want         Paramount    $374,111,707  2000
# 4     5               Dinosaur            Disney    $349,822,765  2000

# %% [markdown]
# Let's practice some data cleaning on the Worldwide Gross column:

# %%
full_df['Worldwide gross'].unique()
# Out:
# array(['$546,388,105', '$460,583,960', '$429,632,142', '$374,111,707',
#        '$349,822,765', '$345,141,403', '$330,444,045', '$328,718,434',
#        '$296,339,527', '$291,420,351', '$974,755,371', '$883,726,270',
#        '$528,773,250', '$487,853,320', '$450,717,150', '$449,220,945',
#        '$433,013,274', '$368,780,809', '$362,211,740', '$351,692,268',
#        '$936,689,735', '$878,979,634', '$821,708,551', '$653,741,940',
#        '$441,818,803', '$431,971,116', '$408,247,917', '$383,257,136',
#        '$368,744,044', '$358,372,926', '$1,140,682,011',
#        '$871,014,978  [2]', '$739,412,035', '$654,264,015',
#        '$484,592,874', '$454,627,263', '$433,371,112', '$427,343,298',
#        '$407,711,549', '$273,339,556', '$928,760,770', '$795,634,069',
#        '$788,976,453', '$631,442,092', '$611,486,736', '$552,639,571',
#        '$522,657,936', '$497,409,852', '$374,583,879', '$362,744,280',
#        '$895,921,036', '$868,352,530', '$745,013,115', '$603,873,119',
#        '$562,363,449', '$542,063,846', '$487,287,646', '$474,968,763',
#        '$371,853,783', '$371,594,210', '$1,066,179,725', '$760,006,945',
#        '$660,998,756', '$606,099,584', '$574,480,841', '$461,983,149',
#        '$460,435,291', '$398,479,497', '$391,081,192', '$384,335,608',
#        '$960,996,492', '$941,676,843', '$894,983,373', '$813,367,380',
#        '$709,709,780', '$623,726,085', '$585,410,052', '$536,414,270',
#        '$459,242,249', '$456,068,181', '$997,000,000  [4]',
#        '$790,653,942', '$631,744,560', '$629,443,428', '$609,841,637',
#        '$603,900,354', '$589,580,482', '$585,366,247', '$521,311,860',
#        '$419,665,568', '$2,744,336,793  [3]  [nb 1]', '$933,959,197',
#        '$886,686,817', '$836,303,693', '$769,679,473', '$735,099,082',
#        '$709,827,462', '$524,028,679', '$485,930,816', '$469,310,836',
#        '$1,066,969,703', '$1,025,467,110', '$956,969,703', '$825,532,764',
#        '$752,600,867', '$698,491,347', '$623,933,331', '$592,461,732',
#        '$543,113,985', '$494,878,759', '$1,342,511,219', '$1,123,794,079',
#        '$1,045,713,802', '$712,205,856', '$694,713,380', '$665,692,281',
#        '$626,137,675', '$586,764,305', '$563,749,323', '$559,852,396',
#        '$1,518,812,988', '$1,108,561,013', '$1,081,041,287',
#        '$1,017,003,568', '$877,244,782', '$829,746,820', '$757,930,663',
#        '$746,921,274', '$694,394,724', '$624,026,776', '$1,280,802,282',
#        '$1,214,811,252', '$970,766,005', '$958,366,855', '$865,011,746',
#        '$788,679,850', '$743,559,607', '$723,192,705', '$668,045,518',
#        '$644,783,140', '$1,104,054,072', '$956,019,788', '$772,776,700',
#        '$758,410,378', '$755,356,711', '$746,045,700', '$714,241,503',
#        '$710,644,566', '$708,982,323', '$677,463,813', '$2,068,223,624',
#        '$1,670,400,637', '$1,515,047,671', '$1,402,805,868',
#        '$1,159,398,397', '$880,674,609', '$857,611,174', '$682,714,267',
#        '$658,344,137', '$630,161,890', '$1,153,304,495', '$1,056,057,273',
#        '$1,028,570,889', '$1,023,784,195', '$966,550,600', '$875,457,937',
#        '$873,634,919', '$814,037,575', '$782,612,155', '$746,846,894',
#        '$1,332,539,889', '$1,263,521,126', '$1,236,005,118',
#        '$1,034,799,409', '$962,077,546', '$880,166,924', '$870,325,439',
#        '$863,756,051', '$854,977,126', '$821,847,012', '$2,048,359,754',
#        '$1,346,913,161', '$1,308,467,944', '$1,242,805,359',
#        '$1,148,461,807', '$903,655,259', '$856,085,151', '$791,115,104',
#        '$785,794,179', '$654,855,901', '$2,797,800,564', '$1,656,943,394',
#        '$1,450,026,933', '$1,131,927,996', '$1,128,274,794',
#        '$1,074,251,311', '$1,074,144,248', '$1,073,394,593',
#        '$1,050,693,953', '$800,100,000  [3]', '$464,760,324',
#        '$450,064,993', '$424,505,244', '$347,100,000', '$308,434,533',
#        '$250,482,863', '$235,155,430', '$201,858,461', '$150,000,000',
#        '$144,983,422'], dtype=object)

# %%
full_df.loc[full_df['Worldwide gross'] == "$997,000,000  [4]"]
# Out:
#     Rank            Title   Distributor    Worldwide gross  Year
# 80     1  The Dark Knight  Warner Bros.  $997,000,000  [4]  2008

# %%
full_df['Worldwide gross'][80].split()[0]
# Out:
# '$997,000,000'

# %%
full_df['Worldwide gross'][1].split()[0]
# Out:
# '$460,583,960'

# %%
full_df['Worldwide gross'] = full_df['Worldwide gross'].map(lambda x: x.split()[0])

# %%
full_df['Worldwide gross'] = full_df['Worldwide gross'].str.replace("$", "").str.replace(",", "").astype(int)

# %%
full_df.head()
# Out:
#    Rank                  Title       Distributor  Worldwide gross  Year
# 0     1  Mission: Impossible 2         Paramount        546388105  2000
# 1     2              Gladiator         Universal        460583960  2000
# 2     3              Cast Away  20th Century Fox        429632142  2000
# 3     4        What Women Want         Paramount        374111707  2000
# 4     5               Dinosaur            Disney        349822765  2000

# %%
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 5 columns):
# Rank               210 non-null int64
# Title              210 non-null object
# Distributor        210 non-null object
# Worldwide gross    210 non-null int64
# Year               210 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 8.3+ KB

# %% [markdown]
# ## Discussion Time!
#
# What else could we do with webscraping? Any project ideas pop into mind? Any useful things on that page we could also use to grab more data? Let's discuss!
#
# - Had URLs in these results - could grab even more data on each movie using those
# - Can loop through any kind of repeatable URL, provided you figure out the pattern!
# - The possibilities are endless... (but don't forget to check the terms of use, don't get in trouble!)
