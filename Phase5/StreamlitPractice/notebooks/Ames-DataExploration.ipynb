# %% [markdown]
# # Ames Housing Data Exploration

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import utils as ut

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
df = pd.read_csv('data/ames.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
ut.describe_df(df)
# Out:
# Dataset Shape: (1460, 81)
#              Name   dtypes  Missing  Uniques First Value Last Value  \
# 0              Id    int64        0     1460           1       1460
# 1      MSSubClass    int64        0       15          60         20
# 2        MSZoning   object        0        5          RL         RL
# 3     LotFrontage  float64      259      110          65         75
# 4         LotArea    int64        0     1073        8450       9937
# 5          Street   object        0        2        Pave       Pave
# 6           Alley   object     1369        2         NaN        NaN
# 7        LotShape   object        0        4         Reg        Reg
# 8     LandContour   object        0        4         Lvl        Lvl
# 9       Utilities   object        0        2      AllPub     AllPub
# 10      LotConfig   object        0        5      Inside     Inside
# 11      LandSlope   object        0        3         Gtl        Gtl
# 12   Neighborhood   object        0       25     CollgCr    Edwards
# 13     Condition1   object        0        9        Norm       Norm
# 14     Condition2   object        0        8        Norm       Norm
# 15       BldgType   object        0        5        1Fam       1Fam
# 16     HouseStyle   object        0        8      2Story     1Story
# 17    OverallQual    int64        0       10           7          5
# 18    OverallCond    int64        0        9           5          6
# 19      YearBuilt    int64        0      112        2003       1965
# 20   YearRemodAdd    int64        0       61        2003       1965
# 21      RoofStyle   object        0        6       Gable      Gable
# 22       RoofMatl   object        0        8     CompShg    CompShg
# 23    Exterior1st   object        0       15     VinylSd    HdBoard
# 24    Exterior2nd   object        0       16     VinylSd    HdBoard
# 25     MasVnrType   object        8        4     BrkFace       None
# 26     MasVnrArea  float64        8      327         196          0
# 27      ExterQual   object        0        4          Gd         Gd
# 28      ExterCond   object        0        5          TA         TA
# 29     Foundation   object        0        6       PConc     CBlock
# 30       BsmtQual   object       37        4          Gd         TA
# 31       BsmtCond   object       37        4          TA         TA
# 32   BsmtExposure   object       38        4          No         No
# 33   BsmtFinType1   object       37        6         GLQ        BLQ
# 34     BsmtFinSF1    int64        0      637         706        830
# 35   BsmtFinType2   object       38        6         Unf        LwQ
# 36     BsmtFinSF2    int64        0      144           0        290
# 37      BsmtUnfSF    int64        0      780         150        136
# 38    TotalBsmtSF    int64        0      721         856       1256
# 39        Heating   object        0        6        GasA       GasA
# 40      HeatingQC   object        0        5          Ex         Gd
# 41     CentralAir   object        0        2           Y          Y
# 42     Electrical   object        1        5       SBrkr      SBrkr
# 43       1stFlrSF    int64        0      753         856       1256
# 44       2ndFlrSF    int64        0      417         854          0
# 45   LowQualFinSF    int64        0       24           0          0
# 46      GrLivArea    int64        0      861        1710       1256
# 47   BsmtFullBath    int64        0        4           1          1
# 48   BsmtHalfBath    int64        0        3           0          0
# 49       FullBath    int64        0        4           2          1
# 50       HalfBath    int64        0        3           1          1
# 51   BedroomAbvGr    int64        0        8           3          3
# 52   KitchenAbvGr    int64        0        4           1          1
# 53    KitchenQual   object        0        4          Gd         TA
# 54   TotRmsAbvGrd    int64        0       12           8          6
# 55     Functional   object        0        7         Typ        Typ
# 56     Fireplaces    int64        0        4           0          0
# 57    FireplaceQu   object      690        5         NaN        NaN
# 58     GarageType   object       81        6      Attchd     Attchd
# 59    GarageYrBlt  float64       81       97        2003       1965
# 60   GarageFinish   object       81        3         RFn        Fin
# 61     GarageCars    int64        0        5           2          1
# 62     GarageArea    int64        0      441         548        276
# 63     GarageQual   object       81        5          TA         TA
# 64     GarageCond   object       81        5          TA         TA
# 65     PavedDrive   object        0        3           Y          Y
# 66     WoodDeckSF    int64        0      274           0        736
# 67    OpenPorchSF    int64        0      202          61         68
# 68  EnclosedPorch    int64        0      120           0          0
# 69      3SsnPorch    int64        0       20           0          0
# 70    ScreenPorch    int64        0       76           0          0
# 71       PoolArea    int64        0        8           0          0
# 72         PoolQC   object     1453        3         NaN        NaN
# 73          Fence   object     1179        4         NaN        NaN
# 74    MiscFeature   object     1406        4         NaN        NaN
# 75        MiscVal    int64        0       21           0          0
# 76         MoSold    int64        0       12           2          6
# 77         YrSold    int64        0        5        2008       2008
# 78       SaleType   object        0        9          WD         WD
# 79  SaleCondition   object        0        6      Normal     Normal
# 80      SalePrice    int64        0      663      208500     147500
#
#    Most Common
# 0            1
# 1           20
# 2           RL
# 3           60
# 4         7200
# 5         Pave
# 6         Grvl
# 7          Reg
# 8          Lvl
# 9       AllPub
# 10      Inside
# 11         Gtl
# 12       NAmes
# 13        Norm
# 14        Norm
# 15        1Fam
# 16      1Story
# 17           5
# 18           5
# 19        2006
# 20        1950
# 21       Gable
# 22     CompShg
# 23     VinylSd
# 24     VinylSd
# 25        None
# 26           0
# 27          TA
# 28          TA
# 29       PConc
# 30          TA
# 31          TA
# 32          No
# 33         Unf
# 34           0
# 35         Unf
# 36           0
# 37           0
# 38           0
# 39        GasA
# 40          Ex
# 41           Y
# 42       SBrkr
# 43         864
# 44           0
# 45           0
# 46         864
# 47           0
# 48           0
# 49           2
# 50           0
# 51           3
# 52           1
# 53          TA
# 54           6
# 55         Typ
# 56           0
# 57          Gd
# 58      Attchd
# 59        2005
# 60         Unf
# 61           2
# 62           0
# 63          TA
# 64          TA
# 65           Y
# 66           0
# 67           0
# 68           0
# 69           0
# 70           0
# 71           0
# 72          Gd
# 73       MnPrv
# 74        Shed
# 75           0
# 76           6
# 77        2009
# 78          WD
# 79      Normal
# 80      140000

# %%
target = 'SalePrice'

used_cols = ['LotArea', '1stFlrSF', 'GrLivArea']

# %%
X = df[used_cols]

y = df[target]

# %%
ut.describe_df(X)
# Out:
# Dataset Shape: (1460, 3)
#         Name dtypes  Missing  Uniques  First Value  Last Value  Most Common
# 0    LotArea  int64        0     1073         8450        9937         7200
# 1   1stFlrSF  int64        0      753          856        1256          864
# 2  GrLivArea  int64        0      861         1710        1256          864

# %%
X.describe()
# Out:
#              LotArea     1stFlrSF    GrLivArea
# count    1460.000000  1460.000000  1460.000000
# mean    10516.828082  1162.626712  1515.463699
# std      9981.264932   386.587738   525.480383
# min      1300.000000   334.000000   334.000000
# 25%      7553.500000   882.000000  1129.500000
# 50%      9478.500000  1087.000000  1464.000000
# 75%     11601.500000  1391.250000  1776.750000
# max    215245.000000  4692.000000  5642.000000

# %%
sns.pairplot(X)

# %%
sns.distplot(y)
